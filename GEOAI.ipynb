# %% [markdown]
# <a href="https://colab.research.google.com/github/jawahirkhaleel/Jawahir/blob/main/GEOAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -U geoai-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.9/632.9 kB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 18.8 MB/s eta 0:00:00
# ...

# %%
import geoai
from geoai import MoondreamGeo
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/parking_lot.tif"
image_path = geoai.download_file(url)
image_path
# Out:
# ...
# 'parking_lot.tif'

# %%
moondream = MoondreamGeo()
moondream.load_image(image_path)
# Out:
# Loading vikhyatk/moondream2...
# config.json:   0%|          | 0.00/277 [00:00<?, ?B/s]
# hf_moondream.py: 0.00B [00:00, ?B/s]
# vision.py: 0.00B [00:00, ?B/s]
# config.py: 0.00B [00:00, ?B/s]
# image_crops.py: 0.00B [00:00, ?B/s]
# layers.py: 0.00B [00:00, ?B/s]
# region.py: 0.00B [00:00, ?B/s]
# utils.py: 0.00B [00:00, ?B/s]
# text.py: 0.00B [00:00, ?B/s]
# rope.py: 0.00B [00:00, ?B/s]
# moondream.py: 0.00B [00:00, ?B/s]
# lora.py: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/69.0 [00:00<?, ?B/s]
# Using device: cpu
# (<PIL.Image.Image image mode=RGB size=1659x938>,
# ...

# %%
m = moondream.show_gui()
m
# Out:
# Map(center=[29.678521500000002, -95.42043100000001], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
gdf = m.last_result_as_gdf
gdf
